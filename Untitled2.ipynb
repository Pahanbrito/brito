# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\5NBRITO'

# %%
import pandas as pd

# %%
data = pd.read_excel('VR_NEW_MasterList_with_frequency_tables.xlsx')

# %%
data.head()
# Out:
#   Media Platform Site Code      District  \
# 0        Outdoor   VR 0101  Kuala Lumpur
# 1        Outdoor   VR 0201  Kuala Lumpur
# 2        Outdoor   VR 0202  Kuala Lumpur
# 3        Outdoor   VR 0203  Kuala Lumpur
# 4        Outdoor   VR 0204  Kuala Lumpur
#
#                                             Location      Media Category  \
# 0       KL South, Jalan Puchong, near Old Klang Road  Outdoor LED Screen
# 1  Federal Highway, heading to Mid Valley and Cheras  Outdoor LED Screen
# 2                   Jalan Damansara, Bukit Damansara  Outdoor LED Screen
# 3                        Jalan Damansara, KL Sentral  Outdoor LED Screen
# 4                        Old Klang Road (Mid Valley)  Outdoor LED Screen
#
#    Price for sqr foot     CPM  \
# 0               20.00  312.50
# 1               41.67  104.17
# 2               41.67   69.44
# 3               41.67   83.33
# 4               41.67  138.89
#
#                                        Material Size  No of Screens  \
# ...
